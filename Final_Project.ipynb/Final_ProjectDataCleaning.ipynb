# %% [markdown]
# - Paper I am using: Variable Importance Measures Suggest Paramount Influence
# of Human Economics on Alien-Species Introductions (Arranz et. al 2025)

# %% [markdown]
# - Now that you've got your data from your paper, lets begin cleaning it up to model.
# - Plot the data

# %%
#clean the data by removing missing/"NA" values
data = data.dropna() #dropping rows with missing values
# create a .csv file of cleaned data
data.to_csv('Dawson_Cleaned.csv', index=False) #saving cleaned data to a new .csv file

# %%
# plot the data from the Dawson data.csv file using the Plants, Ants, Amphibians, Reptiles, Fish, Birds, Mammals, and Spiders columns
import pandas as pd #importing pandas for data manipulation
import matplotlib.pyplot as plt #importing matplotlib for plotting
data = pd.read_csv('Dawson_Cleaned.csv') #reading the Dawson data CSV file into a dataframe

# Column names in the dataframe are capitalized ('Plants', 'Amphibians')
# Use the correct column names to avoid KeyError
plt.plot(data['Plants'], label='Plants') # plotting the Plants column
plt.plot(data['Ants'], label='Ants') # plotting the Ants column
plt.plot(data['Amphibians'], label='Amphibians') # plotting the Amphibians column
plt.plot(data['Reptiles'], label='Reptiles') # plotting the Reptiles column
plt.plot(data['Fish'], label='Fish') # plotting the Fish column
plt.plot(data['Birds'], label='Birds') # plotting the Birds column
plt.plot(data['Mammals'], label='Mammals') # plotting the Mammals column
plt.plot(data['Spiders'], label='Spiders') # plotting the Spiders column
plt.xlabel('Index') # setting x-axis label
plt.ylabel('Count') # setting y-axis label
plt.title('Counts of Various Taxa in CleanedDawson Data') # setting title
plt.legend() # adding legend
plt.show() # displaying the plot

# %% [markdown]
# 1. Describe your data, what your input and output data are
#
# The input data is extracted from the Dawson data .csv. This dataset is comprehensive, including information about the worldwide distribution of alien species richness of eight taxonomic groups and potential environmental and human socioeconomic predictors. The plot above demonstrates the global counts of the eight taxonomic groups in the Dawson data. In this model, the output is the bar graph above visualizing global alien species counts. The output data could be used to examine the variable importance in relationships between environmental and economic factors and global alien species richness after further modeling.
#
# 2. Describe what you plan on doing with it (A -> B) given some input data, what is the output that you are trying to model?
#
# Eventually, I want to use the Dawson dataset to create a random forest model that compares the individual and shared variation of environmental, economic, and human population factors with the success of alien species richness in eight taxonomic groups at a global scale. Since there are so many factors in the Dawson dataset, I might narrow in on the effect of one factor on one taxon in my data training and add on to the model as I build understanding. For the purpose of simplicity, I will look at the relationship between Lat, Lon and Mammals.
#
# 3. What machine learning method from the Scikit Learn package do you think fits well to your data?
#
# Arranz et. al utilized a random forest model to determine the variable importance of intercorrelated environmental and human socioeconomic factors on alien species richness at a global scale. Since the Dawson dataset is so comprehensive, I want to follow in the authors' footsteps and use a random forest model from SciKit learn.
