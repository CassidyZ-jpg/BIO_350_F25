# %% [markdown]
# {
#   "Biological Analysis": [
#     {
#       "title": "Amplicon sequencing vs. whole genome sequencing",
#       "description": "Amplicon sequencing targets specific amplicon sequences for analysis. Whole genome sequencing reads the entire DNA strand. Amplicon sequencing allows for more targeted analysis of specific genes or mutations, while whole genome sequencing allows for an understanding of the complete DNA sequence."
#     },
#     {
#       "title": "DNA barcoding",
#       "description": "DNA barcoding is a method for identifying species using a short DNA sequence from a specific gene. This sequence acts as a 'fingerprint,' and it is kept in a digital library of DNA barcodes used to identify organisms. DNA barcodes are procured through collecting samples, putting them through PCR, and sequencing the DNA."
#     },
#     {
#       "title": "Alpha vs. beta diversity",
#       "description": "Alpha diversity measures the richness and evenness values within a single ecosystem. Richness is the count of different species in an area, while evenness measures how evenly the species are distributed. Beta diversity measures the differences in species composition between two or more communities."
#     }
#   ],
#   "Data Analysis": [
#     {
#       "title": "Extrapolation/normalizing data",
#       "description": "Extrapolation is the process of estimating unknown values by extending known data points beyond their original range. Data normalization is the process of organizing data into tables and/or relationships to reduce redundancy and improve integrity. Data extrapolation is used to make predict values or trends beyond the existing dataset. Data normalization can be used during early stages of data processing to improve data quality."
#     },
#     {
#       "title": "Lag analysis",
#       "description": "Lag analysis is a statistical method used to examine the time delay between an event and its effect. Lags are created by shifting a time series forward or backward in time. This method analyzes the relationship between past and current data points to identify patterns and correlations over time."
#     }
#   ],
#   "Modeling Concepts": [
#     {
#       "title": "Generalized mixed effect model",
#       "description": "Generalized mixed effect models combine generalized linear models with mixed-effect models. They analyze data with non-normal distributions and non-independent observations. They can account for population-level effects and random effects."
#     },
#     {
#       "title": "Linear mixed effect model",
#       "description": "Linear mixed effect models are statistical tools that extends linear regression to handle grouped or hierarchical data by including both fixed and random effects. Fixed effects represent the average relationship across all groups, while random effects account for variability between groups. Linear mixed effect models capture dependencies between groups and provides a more nuanced understanding of the data than a simple linear model."
#     },
#     {
#       "title": "Allometric scale model",
#       "description": "Allometric scale models are models that describe how biological traits or processes change in proportion to an organism's size. It uses a power law relationship (for example, Y=aM^b). Allometric scale models can be used to estimate a drug's behavior on humans based on animal data."
#     },
#     {
#       "title": "Linear vs. logistic regression",
#       "description": "Linear regression is used for predicting continuous numerical values. Logistic regression is used for predicting the probability of a categorical outcome. Linear regression fits a straight line to the data, while logistic regression uses an S-shaped curve."
#     },
#     {
#       "title": "Non-linear regression",
#       "description": "Non-linear regression is a statistical method that models a curved or non-linear relationship between a dependent variable and one or more independent variables. Non-linear regression uses a non-linear equation to find the best-fit curve of a dataset. The relationship between the dependent variable and the parameters is inherently nonlinear."
#     },
#     {
#       "title": "Random forest",
#       "description": "A random forest model is a supervised machine learning algorithm used for both classification and regression tasks. It operates by creating decision trees and using their predictions to produce a more accurate result than a single decision tree. Random forest is used in medical diagnosis as well as financial fraud detection and other fields."
#     },
#      {
#       "title": "Cross-validation and accuracy of models",
#       "description": "Cross-validation is used in machine learning to assess the performance and accuracy of a model. It involves repeatedly splitting datasets into testing and training subsets. Cross-validation can help mitigate overfitting and provide an estimate of a model's accuracy."
#     }
#   ]
# }
